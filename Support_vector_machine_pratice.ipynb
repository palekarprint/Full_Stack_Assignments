# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_blobs, make_moons
from sklearn.model_selection import train_test_split

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, class_sep=2, random_state=2)

# %%
y.shape
# Out:
# (1000,)

# %%
X[:0].shape
# Out:
# (0, 2)

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, class_sep=2, random_state=2)

# %%
plt.scatter(X1[:,0], X1[:,1], c=y1)
plt.show()

# %%
X1, y1 = make_moons(n_samples=1000, random_state=2, noise=0.3)

# %%
plt.scatter(X1[:,0], X1[:,1], c=y1)
plt.show()

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(X1_train, y1_train)
# Out:
# LinearSVC()

# %%
clf.score(X1_train,y1_train)
# Out:
# 0.8413333333333334

# %%
y1_pred = clf.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y1_test,y1_pred)
# Out:
# 0.884

# %%
X2, y2 = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=42)
plt.scatter(X2[:,0], X2[:,1], c=y2)
plt.show()

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2)

# %%
clf = LinearSVC()
clf.fit(X2_train, y2_train)
# Out:
# LinearSVC()

# %%
clf.score(X2_train, y2_train)
# Out:
# 1.0

# %%
y2_pred = clf.predict(X2_test)

# %%
accuracy_score(y2_test, y2_pred)
# Out:
# 1.0
